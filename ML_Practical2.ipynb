# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushmit1480/ProgrammingAssignment2/blob/master/ML_Practical2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #UPLOADING DATASET

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fc14b1c5-21f7-4099-9314-a25319db882b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc14b1c5-21f7-4099-9314-a25319db882b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hospital-data.csv to hospital-data.csv

# %% [markdown]
# #Reading data from uploaded dataset

# %%
import pandas as pd
import io

df  = pd.read_csv(io.BytesIO(uploaded['hospital-data.csv']))

# %% [markdown]
# #Printing data

# %%
df
# Out:
#      Provider Number  ... Emergency Services
# 0             010001  ...                Yes
# 1             010005  ...                Yes
# 2             010006  ...                Yes
# 3             010007  ...                Yes
# 4             010008  ...                Yes
# ...              ...  ...                ...
# 4821          670072  ...                Yes
# 4822          670073  ...                Yes
# 4823          670075  ...                Yes
# 4824          670076  ...                Yes
# 4825          670077  ...                Yes
#
# [4826 rows x 13 columns]

# %% [markdown]
# #Print Only First 5 rows

# %%
df.head()
# Out:
#   Provider Number  ... Emergency Services
# 0          010001  ...                Yes
# 1          010005  ...                Yes
# 2          010006  ...                Yes
# 3          010007  ...                Yes
# 4          010008  ...                Yes
#
# [5 rows x 13 columns]

# %% [markdown]
# #Uploading Another .csv file

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-efa59a44-5328-4b7e-9004-f161b250778b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-efa59a44-5328-4b7e-9004-f161b250778b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Cartwheeldata.csv to Cartwheeldata.csv

# %% [markdown]
# #Read Another .csv File

# %%
read  = pd.read_csv(io.BytesIO(upload['Cartwheeldata.csv']))

# %% [markdown]
# #Print Data

# %%
read
# Out:
#     ID  Age Gender  GenderGroup  ... CWDistance  Complete  CompleteGroup  Score
# 0    1   56      F            1  ...         79         Y              1      7
# 1    2   26      F            1  ...         70         Y              1      8
# 2    3   33      F            1  ...         85         Y              1      7
# 3    4   39      F            1  ...         87         Y              1     10
# 4    5   27      M            2  ...         72         N              0      4
# 5    6   24      M            2  ...         81         N              0      3
# 6    7   28      M            2  ...        107         Y              1     10
# 7    8   22      F            1  ...         98         Y              1      9
# 8    9   29      M            2  ...        106         N              0      5
# 9   10   33      F            1  ...         65         Y              1      8
# 10  11   30      M            2  ...         96         Y              1      6
# ...
